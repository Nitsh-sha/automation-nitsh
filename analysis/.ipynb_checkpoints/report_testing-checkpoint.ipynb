# %%
from config.web_credentials import webconfig
from data_access.database_operations import get_revenue_details_data
from analysis.functions.dataframe_analysis import *
import pandas as pd
import numpy as np
from IPython.display import display

# Defines the start and end dates
start_date = '2023-01-01'
end_date = '2023-01-27'

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.expand_frame_repr', False)

# Database Report
revenue_details_report_mgm_corporate = report(start_date, end_date, get_revenue_details_data, 'corporate', 'MGM Corporate')
display(revenue_details_report_mgm_corporate)

revenue_details_report_mgm_bellagio = report(start_date, end_date, get_revenue_details_data, 'management', 'MGM Bellagio')
display(revenue_details_report_mgm_bellagio)

#official_revenues_breakdown_report = generateofficialreport('UAT', webconfig['email'], webconfig['password'], corporate, 'MGM Corporate', 'Total Revenues', 'Total
# Revenues Breakdown', start_date, end_date)
#display(official_revenues_breakdown_report)

#x = compare_dataframes(revenue_details_report, 'revenues_breakdown_report', official_revenues_breakdown_report, 'official_revenues_breakdown_report')
#print(x)
# Out:
# /Library/Python/3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_8.9p1)
# INFO:paramiko.transport:Authentication (publickey) successful!
# INFO:root:SSH tunnel established successfully.
# INFO:root:SSH tunnel closed.
# Report from PAY, internally titled get_revenue_details_data:
#      Trans Date   Trans Time               Venue  EcoZone  Event Date Currency  Prepaid  Agreed  Charged  Action                                         item        booktype globaltype       pricing  qty  guests   Processor Method Transport         Reference       Brand               Payor Name                   Party Name  Gateway Code  Auth Code        Card Token     Book Code     Conf Code  Trans ID  Trans Book ID    Order Code
# ...

# %%
diff_rows = revenues_breakdown_report.compare(official_revenues_breakdown_report, align_axis=0, keep_shape=True, result_names=("revenues_breakdown_report", "official_revenues_breakdown_report"))
#different_rows = diff_rows[diff_rows['self'] != diff_rows['other']]
# Display the rows with differences
print(diff_rows)
# Out:
#                                        Trans Date Venue  EcoZone Event Date Event Currency  Prepaid  Agreed  Charged Action item booktype globaltype pricing  qty  guests Payor Name Party Name  Auth Code Book Code  Trans ID Order Code BreakDown  LET Tax  Processing Fee  Subtotal  Total
# 0   revenues_breakdown_report                 NaN   NaN      NaN        NaN   NaN      NaN      NaN     NaN      NaN    NaN  NaN      NaN        NaN     NaN  NaN     NaN        NaN        NaN        NaN       NaN       NaN        NaN       NaN      NaN             NaN       NaN    NaN
#     official_revenues_breakdown_report        NaN   NaN      NaN        NaN   NaN      NaN      NaN     NaN      NaN    NaN  NaN      NaN        NaN     NaN  NaN     NaN        NaN        NaN        NaN       NaN       NaN        NaN       NaN      NaN             NaN       NaN    NaN
# ...

# %%
differences = revenues_breakdown_report.compare(official_revenues_breakdown_report)
num_differences = differences.shape[0]
total_elements = revenues_breakdown_report.size
match_percentage = ((total_elements - num_differences) / total_elements) * 100
print(num_differences)
print(match_percentage)
# Out:
# 0
# 100.0

# %%
# Get the list of column names
columns = revenues_breakdown_report.columns

# Iterate through the columns and print the data types side by side
for column in columns:
    data_type_self = revenues_breakdown_report[column].dtype
    data_type_other = official_revenues_breakdown_report[column].dtype
    print(f"{column}: {data_type_self} (Self) - {data_type_other} (Other)")
# Out:
# Trans Date: object (Self) - object (Other)
# Venue: object (Self) - object (Other)
# EcoZone: int64 (Self) - int64 (Other)
# Event Date: object (Self) - object (Other)
# Event: object (Self) - float64 (Other)
# Currency: object (Self) - object (Other)
# Prepaid: float64 (Self) - int64 (Other)
# Agreed: float64 (Self) - int64 (Other)
# Charged: float64 (Self) - float64 (Other)
# Action: object (Self) - object (Other)
# item: object (Self) - object (Other)
# booktype: object (Self) - object (Other)
# globaltype: object (Self) - object (Other)
# pricing: object (Self) - object (Other)
# qty: float64 (Self) - int64 (Other)
# guests: float64 (Self) - int64 (Other)
# Payor Name: object (Self) - object (Other)
# Party Name: object (Self) - object (Other)
# Auth Code: int64 (Self) - int64 (Other)
# Book Code: object (Self) - object (Other)
# Trans ID: int64 (Self) - int64 (Other)
# Order Code: object (Self) - object (Other)
# BreakDown: object (Self) - object (Other)
# ...

# %%
print(revenues_breakdown_report.compare(official_revenues_breakdown_report))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print(revenues_breakdown_report.equals(official_revenues_breakdown_report))
# Out:
# False
